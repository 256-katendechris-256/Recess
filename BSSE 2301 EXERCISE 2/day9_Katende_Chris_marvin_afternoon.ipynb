# %%
#Qtn one
#attempt one
import pandas as pd

# Define the two sample series
series1 = pd.Series([4, 65, 436, 3, 9])
series2 = pd.Series([7, 0, 3, 897, 9])

# Compare the elements of the two series
comparison = series1 == series2

# Print the result
print(comparison)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# dtype: bool

# %%
#second approach
import pandas as pd

# Define the two sample series
series1 = pd.Series([4, 65, 436, 3, 9])
series2 = pd.Series([7, 0, 3, 897, 9])

# Compare the elements of the two series
comparison = series1.equals(series2)

# Print the result
print(comparison)
# Out:
# False

# %% [markdown]
# Question 2

# %%
import pandas as pd

# Define the sample series
series1 = pd.Series([2, 4, 6, 8, 14])
series2 = pd.Series([1, 3, 5, 7, 9])

# Addition
addition = series1 + series2
print("Addition:")
print(addition)

# Subtraction
subtraction = series1 - series2
print("\nSubtraction:")
print(subtraction)

# Multiplication
multiplication = series1 * series2
print("\nMultiplication:")
print(multiplication)

# Division
division = series1 / series2
print("\nDivision:")
print(division)
# Out:
# Addition:
# 0     3
# 1     7
# 2    11
# 3    15
# 4    23
# dtype: int64
#
# Subtraction:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    5
# dtype: int64
#
# Multiplication:
# 0      2
# 1     12
# 2     30
# 3     56
# 4    126
# dtype: int64
#
# Division:
# 0    2.000000
# 1    1.333333
# 2    1.200000
# 3    1.142857
# 4    1.555556
# dtype: float64

# %% [markdown]
# Question 3

# %%
import pandas as pd

# Sample dictionary
dictionary1 = {'Josh': 24, 'Sam': 36, 'Peace': 19, 'Charles': 65, 'Tom': 44}

# Convert the dictionary to a series
series1 = pd.Series(dictionary1)

# Print the resulting series
print(series1)
# Out:
# Josh       24
# Sam        36
# Peace      19
# Charles    65
# Tom        44
# dtype: int64

# %% [markdown]
# Question 4

# %%
import pandas as pd
import numpy as np

# Sample series
series1 = pd.Series(['Love', 800, 'Joy', 789.9, 'Peace', True])

# Convert the series to an array
array1 = np.array(series1)

# Print the resulting array
print(array1)
# Out:
# ['Love' 800 'Joy' 789.9 'Peace' True]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statistics
import scipy as stat
import seaborn as sns

# %%
dara=pd.read_csv('AfricaCupofNationsMatches.csv')
HomeTeems =dara['HomeTeamGoals']
#print(HomeTeams)
Home=pd.Series(HomeTeems)
#most frequent
most_freq=Home.mode()[0]
print("the most frequent value is, ",most_freq)

#replaccing the most frequent value with 'Other'
Home[Home == most_freq] = 'Other'
Home
# Out:
# the most frequent value is,  1.0
# 0      Other
# 1        NaN
# 2        4.0
# 3        4.0
# 4      Other
#        ...
# 617      0.0
# 618    Other
# 619      2.0
# 620      0.0
# 621      0.0
# Name: HomeTeamGoals, Length: 622, dtype: object

# %% [markdown]
# DataFrames

# %% [markdown]
# Question 1 of 20

# %%
dara=pd.read_csv('AfricaCupofNationsMatches.csv')
dara
# Out:
#      Year                      Date   Time      HomeTeam       AwayTeam  \
# 0    1957                  10-Feb-57    NaN       Sudan           Egypt
# 1    1957                  10-Feb-57    NaN    Ethiopia    South Africa
# 2    1957                  16-Feb-57    NaN       Egypt        Ethiopia
# 3    1959                  22-May-59    NaN        Egypt       Ethiopia
# 4    1959                  25-May-59    NaN       Sudan        Ethiopia
# ..    ...                        ...    ...          ...            ...
# 617  2019  11 July 2019 (2019-07-11)  21:00  Madagascar         Tunisia
# 618  2019  14 July 2019 (2019-07-14)  18:00     Senegal         Tunisia
# 619  2019  14 July 2019 (2019-07-14)  21:00     Algeria         Nigeria
# 620  2019  17 July 2019 (2019-07-17)  21:00     Tunisia         Nigeria
# 621  2019  19 July 2019 (2019-07-19)  21:00     Senegal         Algeria
#
#      HomeTeamGoals  AwayTeamGoals                 Stage  \
# ...

# %% [markdown]
# Question 2 of 20

# %%
first_seven=dara.head(7)
#print("First seven rows of the dataset are:" ,first_seven)
first_seven
# Out:
#    Year      Date  Time    HomeTeam       AwayTeam  HomeTeamGoals  \
# 0  1957  10-Feb-57   NaN     Sudan           Egypt            1.0
# 1  1957  10-Feb-57   NaN  Ethiopia    South Africa            NaN
# 2  1957  16-Feb-57   NaN     Egypt        Ethiopia            4.0
# 3  1959  22-May-59   NaN      Egypt       Ethiopia            4.0
# 4  1959  25-May-59   NaN     Sudan        Ethiopia            1.0
# 5  1959  29-May-59   NaN      Egypt          Sudan            2.0
# 6  1962  14-Jan-62   NaN  Ethiopia         Tunisia            4.0
#
#    AwayTeamGoals             Stage  \
# 0            2.0        Semifinals
# 1            NaN        Semifinals
# 2            0.0             Final
# 3            0.0  Final Tournament
# 4            0.0  Final Tournament
# 5            1.0  Final Tournament
# 6            2.0        Semifinals
#
#                                 SpecialWinConditions                 Stadium  \
# ...

# %% [markdown]
# Question 3 of 20

# %%
selected_columns=['HomeTeam', 'AwayTeam', 'HomeTeamGoals','AwayTeamGoals']
selected=dara[selected_columns]
selected
# Out:
#         HomeTeam       AwayTeam  HomeTeamGoals  AwayTeamGoals
# 0         Sudan           Egypt            1.0            2.0
# 1      Ethiopia    South Africa            NaN            NaN
# 2         Egypt        Ethiopia            4.0            0.0
# 3          Egypt       Ethiopia            4.0            0.0
# 4         Sudan        Ethiopia            1.0            0.0
# ..           ...            ...            ...            ...
# 617  Madagascar         Tunisia            0.0            3.0
# 618     Senegal         Tunisia            1.0            0.0
# 619     Algeria         Nigeria            2.0            1.0
# 620     Tunisia         Nigeria            0.0            1.0
# 621     Senegal         Algeria            0.0            1.0
#
# [622 rows x 4 columns]

# %% [markdown]
# Question 4 of 20

# %%
egypt_rows = dara[dara['HomeTeam'] == 'Egypt']
egypt_rows
# Out:
#     Year      Date  Time  HomeTeam   AwayTeam  HomeTeamGoals  AwayTeamGoals  \
# 3   1959  22-May-59   NaN    Egypt   Ethiopia            4.0            0.0
# 5   1959  29-May-59   NaN    Egypt      Sudan            2.0            1.0
# 7   1962  18-Jan-62   NaN    Egypt     Uganda            2.0            1.0
# 13  1963  24-Nov-63   NaN    Egypt    Nigeria            6.0            3.0
# 14  1963  26-Nov-63   NaN    Egypt      Sudan            2.0            2.0
# 16  1963  30-Nov-63   NaN    Egypt   Ethiopia            3.0            0.0
#
#                 Stage SpecialWinConditions                 Stadium  \
# 3    Final Tournament                  NaN   Prince Farouk Stadium
# 5    Final Tournament                  NaN   Prince Farouk Stadium
# 7          Semifinals                  NaN  Hailé Sélassié Stadium
# 13            Group B                  NaN   Kumasi Sports Stadium
# 14            Group B                  NaN   Kumasi Sports Stadium
# ...

# %% [markdown]
# Question 5 of 20

# %%
num_rows = dara.shape[0]
num_columns = dara.shape[1]

# Print the counts
print("Number of rows:", num_rows)
print("Number of columns:", num_columns)
# Out:
# Number of rows: 622
# Number of columns: 12

# %% [markdown]
# Question 6 of 20

# %%
empty=dara[dara['Attendance'].isna()]
print(empty)
# Out:
#      Year                         Date   Time        HomeTeam       AwayTeam  \
# 1    1957                     10-Feb-57    NaN      Ethiopia    South Africa
# 8    1962                     20-Jan-62    NaN       Tunisia          Uganda
# 9    1962                     21-Jan-62    NaN      Ethiopia           Egypt
# 10   1963                     24-Nov-63    NaN         Ghana         Tunisia
# 11   1963                     26-Nov-63    NaN         Ghana        Ethiopia
# ..    ...                           ...    ...            ...            ...
# 565  2017  29 January 2017 (2017-01-29)  20:00         Egypt         Morocco
# 566  2017  1 February 2017 (2017-02-01)  20:00  Burkina Faso           Egypt
# 567  2017  2 February 2017 (2017-02-02)  20:00      Cameroon           Ghana
# 568  2017  4 February 2017 (2017-02-04)  20:00  Burkina Faso           Ghana
# 569  2017  5 February 2017 (2017-02-05)  20:00         Egypt        Cameroon
#
# ...

# %% [markdown]
# Question 7 of 20

# %%
#select the rows where the ‘HomeTeamGoals’ are between 3 and 6 inclusive.
selected_rows = dara[(dara['HomeTeamGoals'] >= 3) & (dara['HomeTeamGoals'] <= 6)]

# Print the selected rows
print(selected_rows)
# Out:
#      Year                         Date   Time    HomeTeam     AwayTeam  \
# 2    1957                     16-Feb-57    NaN     Egypt      Ethiopia
# 3    1959                     22-May-59    NaN      Egypt     Ethiopia
# 6    1962                     14-Jan-62    NaN  Ethiopia       Tunisia
# 8    1962                     20-Jan-62    NaN   Tunisia        Uganda
# 9    1962                     21-Jan-62    NaN  Ethiopia         Egypt
# ..    ...                           ...    ...        ...          ...
# 553  2017  20 January 2017 (2017-01-20)  20:00   Morocco          Togo
# 585  2019     27 June 2019 (2019-06-27)  22:00     Kenya      Tanzania
# 595  2019     24 June 2019 (2019-06-24)  22:00      Mali    Mauritania
# 608  2019      6 July 2019 (2019-07-06)  18:00   Nigeria      Cameroon
# 611  2019      7 July 2019 (2019-07-07)  21:00   Algeria        Guinea
#
#      HomeTeamGoals  AwayTeamGoals              Stage    SpecialWinConditions  \
# ...

# %% [markdown]
# Question 8 of 20

# %%
# Change the "AwayTeamGoals" in the 3rd row to 10
dara.loc[2, 'AwayTeamGoals'] = 10

# Print the updated DataFrame
print(dara)
# Out:
#      Year                      Date   Time      HomeTeam       AwayTeam  \
# 0    1957                  10-Feb-57    NaN       Sudan           Egypt
# 1    1957                  10-Feb-57    NaN    Ethiopia    South Africa
# 2    1957                  16-Feb-57    NaN       Egypt        Ethiopia
# 3    1959                  22-May-59    NaN        Egypt       Ethiopia
# 4    1959                  25-May-59    NaN       Sudan        Ethiopia
# ..    ...                        ...    ...          ...            ...
# 617  2019  11 July 2019 (2019-07-11)  21:00  Madagascar         Tunisia
# 618  2019  14 July 2019 (2019-07-14)  18:00     Senegal         Tunisia
# 619  2019  14 July 2019 (2019-07-14)  21:00     Algeria         Nigeria
# 620  2019  17 July 2019 (2019-07-17)  21:00     Tunisia         Nigeria
# 621  2019  19 July 2019 (2019-07-19)  21:00     Senegal         Algeria
#
#      HomeTeamGoals  AwayTeamGoals                 Stage  \
# ...

# %% [markdown]
# Question 9 of 20

# %%
# Sort the DataFrame by 'HomeTeam' in ascending order and 'HomeTeamScores' in descending order
sorted_dara = dara.sort_values(by=['HomeTeam', 'HomeTeamGoals'], ascending=[True, False])

# Print the sorted DataFrame
sorted_dara
# Out:
#      Year                         Date           Time    HomeTeam  \
# 205  1990                      2-Mar-90            NaN   Algeria
# 29   1968                     14-Jan-68            NaN   Algeria
# 135  1980                     16-Mar-80            NaN   Algeria
# 164  1984                      5-Mar-84            NaN   Algeria
# 171  1984                     17-Mar-84            NaN   Algeria
# ..    ...                           ...            ...        ...
# 521  2012                     12-Feb-12  20:30[note 1]    Zambia
# 549  2017  23 January 2017 (2017-01-23)          20:00  Zimbabwe
# 398  2004                     25-Jan-04          16:30  Zimbabwe
# 437  2006                     23-Jan-06          20:00  Zimbabwe
# 575  2019     30 June 2019 (2019-06-30)          21:00  Zimbabwe
#
#          AwayTeam  HomeTeamGoals  AwayTeamGoals              Stage  \
# 205       Nigeria            5.0            1.0            Group A
# ...

# %% [markdown]
# Question 10 of 20

# %%
column_headers=list(dara.columns)
column_headers
# Out:
# ['Year',
#  'Date ',
#  'Time ',
#  'HomeTeam',
#  'AwayTeam',
#  'HomeTeamGoals',
#  'AwayTeamGoals',
#  'Stage',
#  'SpecialWinConditions',
#  'Stadium',
#  'City',
#  'Attendance']

# %% [markdown]
# Question 11 of 20

# %%
# Create a new column
new_column = [1, 2, 3, 4, 5]  # Example data for the new column

# Check if the length of the new column matches the length of the DataFrame
if len(new_column) == len(dara):
    # Append the new column to the DataFrame
    dara['NewColumn'] = new_column

    # Print the updated DataFrame
    print(dara)
else:
    # Print an error message
    print("Length of the new column does not match the length of the DataFrame")
# Out:
# Length of the new column does not match the length of the DataFrame

# %%
dara.columns
# Out:
# Index(['Year', 'Date ', 'Time ', 'HomeTeam', 'AwayTeam', 'HomeTeamGoals',
#        'AwayTeamGoals', 'Stage', 'SpecialWinConditions', 'Stadium', 'City',
#        'Attendance'],
#       dtype='object')

# %% [markdown]
# Question 12 of 20

# %%
# Create two new rows as dictionaries
new_row1 = {'Year': 2034, 'Date ': '12/07/2009', 'Time ':' ','HomeTeam': 'Italy', 'AwayTeam': 'France', 'HomeTeamGoals':4.0,
       'AwayTeamGoals': 3.0, 'Stage':'Finals', 'SpecialWinConditions':" ", 'Stadium':'Wembly', 'City':'London',
       'Attendance':' '}  # Replace 'Column1', 'Column2', etc., with the actual column names and provide values
new_row2 = {'Year': 2024, 'Date ': '12/07/2019', 'Time ':' ','HomeTeam': 'Kenya', 'AwayTeam': 'Iceland', 'HomeTeamGoals':6.0,
       'AwayTeamGoals': 3.0, 'Stage':'Finals', 'SpecialWinConditions':" ", 'Stadium':'Wembly', 'City':'London',
       'Attendance':' '}   # Replace 'Column1', 'Column2', etc., with the actual column names and provide values

# Append the new rows to the DataFrame
dara = pd.concat([dara, pd.DataFrame(new_row1, index=[0])], ignore_index=True)
dara = pd.concat([dara, pd.DataFrame(new_row2, index=[0])], ignore_index=True)
# Print the updated DataFrame
dara
# Out:
#      Year                      Date   Time    HomeTeam       AwayTeam  \
# 0    1957                  10-Feb-57    NaN     Sudan           Egypt
# 1    1957                  10-Feb-57    NaN  Ethiopia    South Africa
# 2    1957                  16-Feb-57    NaN     Egypt        Ethiopia
# 3    1959                  22-May-59    NaN      Egypt       Ethiopia
# 4    1959                  25-May-59    NaN     Sudan        Ethiopia
# ..    ...                        ...    ...        ...            ...
# 621  2019  19 July 2019 (2019-07-19)  21:00   Senegal         Algeria
# 622  2034                 12/07/2009             Italy         France
# 623  2024                 12/07/2019             Kenya        Iceland
# 624  2034                 12/07/2009             Italy         France
# 625  2024                 12/07/2019             Kenya        Iceland
#
#      HomeTeamGoals  AwayTeamGoals             Stage  \
# 0              1.0            2.0        Semifinals
# ...

# %% [markdown]
# Question 13 of 20

# %%
# Change 'Uganda' to 'China' in the 'AwayTeam' column
dara.loc[dara['AwayTeam'] == 'Uganda', 'AwayTeam'] = 'China'

# Print the updated DataFrame
dara
# Out:
#      Year                      Date   Time    HomeTeam       AwayTeam  \
# 0    1957                  10-Feb-57    NaN     Sudan           Egypt
# 1    1957                  10-Feb-57    NaN  Ethiopia    South Africa
# 2    1957                  16-Feb-57    NaN     Egypt        Ethiopia
# 3    1959                  22-May-59    NaN      Egypt       Ethiopia
# 4    1959                  25-May-59    NaN     Sudan        Ethiopia
# ..    ...                        ...    ...        ...            ...
# 621  2019  19 July 2019 (2019-07-19)  21:00   Senegal         Algeria
# 622  2034                 12/07/2009             Italy         France
# 623  2024                 12/07/2019             Kenya        Iceland
# 624  2034                 12/07/2009             Italy         France
# 625  2024                 12/07/2019             Kenya        Iceland
#
#      HomeTeamGoals  AwayTeamGoals             Stage  \
# 0              1.0            2.0        Semifinals
# ...

# %% [markdown]
# Question 14 of 20

# %%
# Reset the index of the DataFrame
dara = dara.reset_index(drop=True)

# Print the DataFrame with reset index
dara
# Out:
#      Year                      Date   Time    HomeTeam       AwayTeam  \
# 0    1957                  10-Feb-57    NaN     Sudan           Egypt
# 1    1957                  10-Feb-57    NaN  Ethiopia    South Africa
# 2    1957                  16-Feb-57    NaN     Egypt        Ethiopia
# 3    1959                  22-May-59    NaN      Egypt       Ethiopia
# 4    1959                  25-May-59    NaN     Sudan        Ethiopia
# ..    ...                        ...    ...        ...            ...
# 621  2019  19 July 2019 (2019-07-19)  21:00   Senegal         Algeria
# 622  2034                 12/07/2009             Italy         France
# 623  2024                 12/07/2019             Kenya        Iceland
# 624  2034                 12/07/2009             Italy         France
# 625  2024                 12/07/2019             Kenya        Iceland
#
#      HomeTeamGoals  AwayTeamGoals             Stage  \
# 0              1.0            2.0        Semifinals
# ...

# %% [markdown]
# Question 15 of 20

# %%
# Check if 'Stadium' column is present in the DataFrame
if 'Stadium' in dara.columns:
    print("The 'Stadium' column is present in the DataFrame.")
else:
    print("The 'Stadium' column is not present in the DataFrame.")
# Out:
# The 'Stadium' column is present in the DataFrame.

# %% [markdown]
# Question 16 of 20

# %%
# Convert the datatype of 'AwayTeamGoals' to float
dara['AwayTeamGoals'] = dara['AwayTeamGoals'].astype(float)

# Print the updated DataFrame
dara
# Out:
#      Year                      Date   Time    HomeTeam       AwayTeam  \
# 0    1957                  10-Feb-57    NaN     Sudan           Egypt
# 1    1957                  10-Feb-57    NaN  Ethiopia    South Africa
# 2    1957                  16-Feb-57    NaN     Egypt        Ethiopia
# 3    1959                  22-May-59    NaN      Egypt       Ethiopia
# 4    1959                  25-May-59    NaN     Sudan        Ethiopia
# ..    ...                        ...    ...        ...            ...
# 621  2019  19 July 2019 (2019-07-19)  21:00   Senegal         Algeria
# 622  2034                 12/07/2009             Italy         France
# 623  2024                 12/07/2019             Kenya        Iceland
# 624  2034                 12/07/2009             Italy         France
# 625  2024                 12/07/2019             Kenya        Iceland
#
#      HomeTeamGoals  AwayTeamGoals             Stage  \
# 0              1.0            2.0        Semifinals
# ...

# %% [markdown]
# Question 17 of 20

# %%
# Remove the last 10 rows from the DataFrame
dara = dara[:-10]

# Print the updated DataFrame
dara
# Out:
#      Year                      Date   Time    HomeTeam       AwayTeam  \
# 0    1957                  10-Feb-57    NaN     Sudan           Egypt
# 1    1957                  10-Feb-57    NaN  Ethiopia    South Africa
# 2    1957                  16-Feb-57    NaN     Egypt        Ethiopia
# 3    1959                  22-May-59    NaN      Egypt       Ethiopia
# 4    1959                  25-May-59    NaN     Sudan        Ethiopia
# ..    ...                        ...    ...        ...            ...
# 611  2019   7 July 2019 (2019-07-07)  21:00   Algeria          Guinea
# 612  2019   8 July 2019 (2019-07-08)  18:00      Mali     Ivory Coast
# 613  2019   8 July 2019 (2019-07-08)  21:00     Ghana         Tunisia
# 614  2019  10 July 2019 (2019-07-10)  18:00   Senegal           Benin
# 615  2019  10 July 2019 (2019-07-10)  21:00   Nigeria    South Africa
#
#      HomeTeamGoals  AwayTeamGoals             Stage  \
# 0              1.0            2.0        Semifinals
# ...

# %% [markdown]
# Question 18 of 20

# %%
for index, row in dara.iterrows():
    # Access row values using row['column_name']
    print(row['Year'], row['Date '])
# Out:
# 1957 10-Feb-57
# 1957 10-Feb-57
# 1957 16-Feb-57
# 1959 22-May-59
# 1959 25-May-59
# 1959 29-May-59
# 1962 14-Jan-62
# 1962 18-Jan-62
# 1962 20-Jan-62
# 1962 21-Jan-62
# 1963 24-Nov-63
# 1963 26-Nov-63
# 1963 28-Nov-63
# 1963 24-Nov-63
# 1963 26-Nov-63
# 1963 28-Nov-63
# 1963 30-Nov-63
# 1963 1-Dec-63
# 1965 12-Nov-65
# 1965 14-Nov-65
# 1965 19-Nov-65
# 1965 12-Nov-65
# 1965 14-Nov-65
# 1965 19-Nov-65
# 1965 21-Nov-65
# 1965 21-Nov-65
# 1968 12-Jan-68
# 1968 12-Jan-68
# 1968 14-Jan-68
# 1968 14-Jan-68
# 1968 16-Jan-68
# 1968 16-Jan-68
# 1968 12-Jan-68
# 1968 12-Jan-68
# 1968 14-Jan-68
# 1968 14-Jan-68
# 1968 16-Jan-68
# 1968 16-Jan-68
# 1968 19-Jan-68
# 1968 19-Jan-68
# 1968 21-Jan-68
# 1968 21-Jan-68
# 1970 6-Feb-70
# 1970 6-Feb-70
# 1970 8-Feb-70
# 1970 8-Feb-70
# 1970 10-Feb-70
# 1970 10-Feb-70
# 1970 7-Feb-70
# 1970 7-Feb-70
# 1970 9-Feb-70
# 1970 9-Feb-70
# 1970 11-Feb-70
# 1970 11-Feb-70
# 1970 14-Feb-70
# 1970 14-Feb-70
# 1970 16-Feb-70
# 1970 16-Feb-70
# 1972 23-Feb-72
# ...

# %%
dara.columns
# Out:
# Index(['Year', 'Date ', 'Time ', 'HomeTeam', 'AwayTeam', 'HomeTeamGoals',
#        'AwayTeamGoals', 'Stage', 'SpecialWinConditions', 'Stadium', 'City',
#        'Attendance'],
#       dtype='object')

# %%
column_order = ['HomeTeam','AwayTeam','HomeTeamGoals','Stage', 'AwayTeamGoals','Attendance','Date ', 'City','Stadium',]  # Replace with your desired column order

# Rearrange the columns based on the defined order
dara = dara[column_order]

# Print the DataFrame with the updated column order
dara
# Out:
#       HomeTeam       AwayTeam  HomeTeamGoals             Stage  AwayTeamGoals  \
# 0       Sudan           Egypt            1.0        Semifinals            2.0
# 1    Ethiopia    South Africa            NaN        Semifinals            NaN
# 2       Egypt        Ethiopia            4.0             Final           10.0
# 3        Egypt       Ethiopia            4.0  Final Tournament            0.0
# 4       Sudan        Ethiopia            1.0  Final Tournament            0.0
# ..         ...            ...            ...               ...            ...
# 611   Algeria          Guinea            3.0       Round of 16            0.0
# 612      Mali     Ivory Coast            0.0       Round of 16            1.0
# 613     Ghana         Tunisia            1.0       Round of 16            1.0
# 614   Senegal           Benin            1.0    Quarter-finals            0.0
# 615   Nigeria    South Africa            2.0    Quarter-finals            1.0
#
# ...

# %% [markdown]
# Question 20 of 20

# %%
# Filter rows where 'HomeTeamGoals' is not equal to 0
dara= dara[dara['HomeTeamGoals'] != 0]

# Reset the index of the DataFrame
dara = dara.reset_index(drop=True)

# Print the updated DataFrame
dara
# Out:
#         HomeTeam       AwayTeam  HomeTeamGoals             Stage  \
# 0         Sudan           Egypt            1.0        Semifinals
# 1      Ethiopia    South Africa            NaN        Semifinals
# 2         Egypt        Ethiopia            4.0             Final
# 3          Egypt       Ethiopia            4.0  Final Tournament
# 4         Sudan        Ethiopia            1.0  Final Tournament
# ..           ...            ...            ...               ...
# 486  Madagascar        DR Congo            2.0       Round of 16
# 487     Algeria          Guinea            3.0       Round of 16
# 488       Ghana         Tunisia            1.0       Round of 16
# 489     Senegal           Benin            1.0    Quarter-finals
# 490     Nigeria    South Africa            2.0    Quarter-finals
#
#      AwayTeamGoals Attendance                      Date          City  \
# 0              2.0    30000.0                  10-Feb-57     Khartoum
# ...
