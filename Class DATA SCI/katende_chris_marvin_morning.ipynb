# %%
#importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
#loading dataset
data = pd.read_csv('bse_dataset.csv')

# %%
data
# Out:
#               Timestamp What is your gender?  Age What is your emotion?  \
# 0   05/07/2023 09:38:39                 Male   21               Content
# 1   05/07/2023 09:38:57        Marabou stock   45                 Weird
# 2   05/07/2023 09:39:09              Female    20                 Happy
# 3   05/07/2023 09:39:12                 Male   21                 Happy
# 4   05/07/2023 09:39:14               Female   21                 Happy
# ..                  ...                  ...  ...                   ...
# 92  05/07/2023 09:53:56              Female    68                   Sad
# 93  05/07/2023 09:54:13                 Male   29               Hopeful
# 94  05/07/2023 09:54:28                 Male   22      Fighting poverty
# 95  05/07/2023 09:54:36                 Male   23          good and bad
# 96  05/07/2023 09:54:52                 male   30                hunger
#
#    Year of birth What is your CGPA? Do you have a Girl Friend or BOY Friend  \
# ...

# %%
#first things first shape of the data number of raws and columns
data.shape
# Out:
# (97, 11)

# %%
data.columns
# Out:
# Index(['Timestamp', 'What is your gender?', 'Age', 'What is your emotion?',
#        'Year of birth', 'What is your CGPA?',
#        'Do you have a Girl Friend or BOY Friend', 'Do you have Depression?',
#        'Do you have Anxiety?', 'Do you have Panic attack?',
#        'Did you have seek any specialist for a treatment? '],
#       dtype='object')

# %%
#getting information about the dataset that is the datatypes
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97 entries, 0 to 96
# Data columns (total 11 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   Timestamp                                           97 non-null     object
#  1   What is your gender?                                97 non-null     object
#  2   Age                                                 97 non-null     int64
#  3   What is your emotion?                               96 non-null     object
#  4   Year of birth                                       97 non-null     object
#  5   What is your CGPA?                                  97 non-null     object
#  6   Do you have a Girl Friend or BOY Friend             97 non-null     object
#  7   Do you have Depression?                             97 non-null     object
# ...

# %% [markdown]
# HANDLING MISSING DATA

# %%
data.isnull()  # Returns a Boolean DataFrame indicating missing values
data.isnull().sum()  # Returns the count of missing values in each column
# Out:
# Timestamp                                             0
# What is your gender?                                  0
# Age                                                   0
# What is your emotion?                                 1
# Year of birth                                         0
# What is your CGPA?                                    0
# Do you have a Girl Friend or BOY Friend               0
# Do you have Depression?                               0
# Do you have Anxiety?                                  0
# Do you have Panic attack?                             0
# Did you have seek any specialist for a treatment?     0
# dtype: int64

# %%
data.dropna()  # Drops rows with any missing values
dag=data.dropna(subset=['What is your emotion?'])  # Drops rows with missing values in specific columns
dag
# Out:
#               Timestamp What is your gender?  Age What is your emotion?  \
# 0   05/07/2023 09:38:39                 Male   21               Content
# 1   05/07/2023 09:38:57        Marabou stock   45                 Weird
# 2   05/07/2023 09:39:09              Female    20                 Happy
# 3   05/07/2023 09:39:12                 Male   21                 Happy
# 4   05/07/2023 09:39:14               Female   21                 Happy
# ..                  ...                  ...  ...                   ...
# 92  05/07/2023 09:53:56              Female    68                   Sad
# 93  05/07/2023 09:54:13                 Male   29               Hopeful
# 94  05/07/2023 09:54:28                 Male   22      Fighting poverty
# 95  05/07/2023 09:54:36                 Male   23          good and bad
# 96  05/07/2023 09:54:52                 male   30                hunger
#
#    Year of birth What is your CGPA? Do you have a Girl Friend or BOY Friend  \
# ...

# %%
dag.isnull().sum()
# Out:
# Timestamp                                             0
# What is your gender?                                  0
# Age                                                   0
# What is your emotion?                                 0
# Year of birth                                         0
# What is your CGPA?                                    0
# Do you have a Girl Friend or BOY Friend               0
# Do you have Depression?                               0
# Do you have Anxiety?                                  0
# Do you have Panic attack?                             0
# Did you have seek any specialist for a treatment?     0
# dtype: int64

# %%
dat=data.fillna('sad')  # Replace missing values with a specific value
#date=data.fillna(data.mean())  # Replace missing values with the mean of the column
dat
#date
# Out:
# /tmp/ipykernel_16095/1041649090.py:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   date=data.fillna(data.mean())  # Replace missing values with the mean of the column
#               Timestamp What is your gender?  Age What is your emotion?  \
# 0   05/07/2023 09:38:39                 Male   21               Content
# 1   05/07/2023 09:38:57        Marabou stock   45                 Weird
# 2   05/07/2023 09:39:09              Female    20                 Happy
# 3   05/07/2023 09:39:12                 Male   21                 Happy
# 4   05/07/2023 09:39:14               Female   21                 Happy
# ..                  ...                  ...  ...                   ...
# 92  05/07/2023 09:53:56              Female    68                   Sad
# ...

# %%
dat.isnull().sum()
# Out:
# Timestamp                                             0
# What is your gender?                                  0
# Age                                                   0
# What is your emotion?                                 0
# Year of birth                                         0
# What is your CGPA?                                    0
# Do you have a Girl Friend or BOY Friend               0
# Do you have Depression?                               0
# Do you have Anxiety?                                  0
# Do you have Panic attack?                             0
# Did you have seek any specialist for a treatment?     0
# dtype: int64

# %% [markdown]
# HANDLING DUPLICATES

# %%
data.duplicated()  # Returns a Boolean Series indicating duplicate rows
#data.drop_duplicates()  # Drops duplicate rows
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 92    False
# 93    False
# 94    False
# 95    False
# 96    False
# Length: 97, dtype: bool
